# %%
pip install sqlalchemy
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: sqlalchemy in c:\users\alexander\appdata\roaming\python\python310\site-packages (1.4.31)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\alexander\appdata\roaming\python\python310\site-packages (from sqlalchemy) (1.1.2)

# %%
pip install scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scipy in c:\users\alexander\appdata\roaming\python\python310\site-packages (1.8.0)
# Requirement already satisfied: numpy<1.25.0,>=1.17.3 in c:\program files\python310\lib\site-packages (from scipy) (1.21.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pymysql
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pymysql in c:\users\alexander\appdata\roaming\python\python310\site-packages (1.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pandas.io import sql
import pandas as pd
import sqlalchemy as db
from datetime import datetime, date
import numpy as np
from scipy import stats
import pymysql

# %%
df = pd.read_csv("covid.csv")
 
print(df)
# Out:
#       infografia      fecha   hora  id_provincia  nombre_provincia  id_canton  \
# 0              2  13/3/2020  17:00             9            guayas        901
# 1              2  13/3/2020  17:00            12          los rios       1201
# 2              2  13/3/2020  17:00            17         pichincha       1701
# 3              2  13/3/2020  17:00            21         Sucumbios       2101
# 4              3  14/3/2020  15:00             1             azuay        101
# ...          ...        ...    ...           ...               ...        ...
# 4511          59  23/4/2020   8:00            19  zamora chinchipe       1901
# 4512          59  23/4/2020   8:00            19  zamora chinchipe       1907
# 4513          59  23/4/2020   8:00            20         galapagos       2001
# 4514          59  23/4/2020   8:00            20         galapagos       2002
# 4515          59  23/4/2020   8:00            20         galapagos       2003
#
#              nombre_canton cerco_epid_act  Casos confirmados  \
# 0                guayaquil            279                  7
# 1                 babahoyo            279                 11
# 2                    quito            279                  4
# 3               lago agrio            279                  1
# 4                   cuenca            317                  1
# ...                    ...            ...                ...
# 4511                Zamora            NaN                 15
# 4512  centinela del condor            NaN                  3
# 4513         san cristobal            NaN                 13
# 4514               isabela            NaN                  3
# 4515            santa cruz            NaN                 38
#
#       poblacion_canton poblacion_provincia
# 0              2723665             4387434
# 1               175281              921763
# 2              2781641             3228233
# 3               119594              230503
# 4               636996              881394
# ...                ...                 ...
# 4511             32761              120416
# 4512              8313              120416
# 4513              9667               33042
# 4514              3073               33042
# 4515             20302               33042
#
# [4516 rows x 11 columns]

# %%
df.head(10)
# Out:
#    infografia      fecha   hora  id_provincia nombre_provincia  id_canton  \
# 0           2  13/3/2020  17:00             9           guayas        901
# 1           2  13/3/2020  17:00            12         los rios       1201
# 2           2  13/3/2020  17:00            17        pichincha       1701
# 3           2  13/3/2020  17:00            21        Sucumbios       2101
# 4           3  14/3/2020  15:00             1            azuay        101
# 5           3  14/3/2020  15:00             9           guayas        901
# 6           3  14/3/2020  15:00            12         los rios       1201
# 7           3  14/3/2020  15:00            17        pichincha       1701
# 8           3  14/3/2020  15:00            21        Sucumbios       2101
# 9           5  15/3/2020  18:00             1            azuay        101
#
#   nombre_canton cerco_epid_act  Casos confirmados  poblacion_canton  \
# 0     guayaquil            279                  7           2723665
# 1      babahoyo            279                 11            175281
# 2         quito            279                  4           2781641
# 3    lago agrio            279                  1            119594
# 4        cuenca            317                  1            636996
# 5     guayaquil            317                 11           2723665
# 6      babahoyo            317                 11            175281
# 7         quito            317                  4           2781641
# 8    lago agrio            317                  1            119594
# 9        cuenca            273                  1            636996
#
#   poblacion_provincia
# 0             4387434
# 1              921763
# 2             3228233
# 3              230503
# 4              881394
# 5             4387434
# 6              921763
# 7             3228233
# 8              230503
# 9              881394

# %%
database_username = 'root'
database_password = '1717514945'
database_ip       = 'localhost'
database_name    = 'covidecuador'
database_connection = db.create_engine('mysql+pymysql://{0}:{1}@{2}/{3}'.format(database_username, database_password, database_ip, database_name))

connection= database_connection.connect()
metadata = db.MetaData()

# %%
df.to_sql('covid_ecuador', connection)
